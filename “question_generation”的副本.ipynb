# %%
# !pip install -U transformers==3.0.0
# Out:
# Collecting transformers==3.0.0
#   Using cached transformers-3.0.0-py3-none-any.whl (754 kB)
# Requirement already satisfied: packaging in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (21.3)
# Requirement already satisfied: filelock in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (3.6.0)
# Collecting tokenizers==0.8.0-rc4
#   Using cached tokenizers-0.8.0rc4.tar.gz (96 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: sacremoses in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (0.0.49)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (2022.3.15)
# Requirement already satisfied: requests in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (2.27.1)
# Requirement already satisfied: numpy in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (1.22.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from transformers==3.0.0) (4.64.0)
# Requirement already satisfied: colorama in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from tqdm>=4.27->transformers==3.0.0) (0.4.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from packaging->transformers==3.0.0) (3.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from requests->transformers==3.0.0) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from requests->transformers==3.0.0) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from requests->transformers==3.0.0) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from requests->transformers==3.0.0) (2021.10.8)
# Requirement already satisfied: six in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from sacremoses->transformers==3.0.0) (1.16.0)
# Requirement already satisfied: click in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from sacremoses->transformers==3.0.0) (8.1.2)
# Requirement already satisfied: joblib in c:\users\aorus\desktop\open_qg-master\venv\lib\site-packages (from sacremoses->transformers==3.0.0) (1.1.0)
# Building wheels for collected packages: tokenizers
#   Building wheel for tokenizers (PEP 517): started
#   Building wheel for tokenizers (PEP 517): finished with status 'error'
# Failed to build tokenizers
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\AORUS\Desktop\Open_QG-master\venv\Scripts\python.exe' 'C:\Users\AORUS\Desktop\Open_QG-master\venv\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\AORUS\AppData\Local\Temp\tmpy2uht_4k'
#        cwd: C:\Users\AORUS\AppData\Local\Temp\pip-install-__hialvw\tokenizers_7f421b1e798c4469a307aca8137a84c7
#   Complete output (48 lines):
#   C:\Users\AORUS\AppData\Local\Temp\pip-build-env-o2cjyle6\overlay\Lib\site-packages\setuptools\dist.py:516: UserWarning: Normalizing '0.8.0.rc4' to '0.8.0rc4'
#     warnings.warn(tmpl.format(**locals()))
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\tokenizers
#   copying tokenizers\__init__.py -> build\lib.win-amd64-3.9\tokenizers
#   creating build\lib.win-amd64-3.9\tokenizers\models
#   copying tokenizers\models\__init__.py -> build\lib.win-amd64-3.9\tokenizers\models
#   creating build\lib.win-amd64-3.9\tokenizers\decoders
#   copying tokenizers\decoders\__init__.py -> build\lib.win-amd64-3.9\tokenizers\decoders
#   creating build\lib.win-amd64-3.9\tokenizers\normalizers
#   copying tokenizers\normalizers\__init__.py -> build\lib.win-amd64-3.9\tokenizers\normalizers
#   creating build\lib.win-amd64-3.9\tokenizers\pre_tokenizers
#   copying tokenizers\pre_tokenizers\__init__.py -> build\lib.win-amd64-3.9\tokenizers\pre_tokenizers
#   creating build\lib.win-amd64-3.9\tokenizers\processors
#   copying tokenizers\processors\__init__.py -> build\lib.win-amd64-3.9\tokenizers\processors
#   creating build\lib.win-amd64-3.9\tokenizers\trainers
#   copying tokenizers\trainers\__init__.py -> build\lib.win-amd64-3.9\tokenizers\trainers
#   creating build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\implementations\base_tokenizer.py -> build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\implementations\bert_wordpiece.py -> build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\implementations\byte_level_bpe.py -> build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\implementations\char_level_bpe.py -> build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\implementations\sentencepiece_bpe.py -> build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\implementations\__init__.py -> build\lib.win-amd64-3.9\tokenizers\implementations
#   copying tokenizers\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers
#   copying tokenizers\models\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers\models
#   copying tokenizers\decoders\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers\decoders
#   copying tokenizers\normalizers\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers\normalizers
#   copying tokenizers\pre_tokenizers\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers\pre_tokenizers
#   copying tokenizers\processors\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers\processors
#   copying tokenizers\trainers\__init__.pyi -> build\lib.win-amd64-3.9\tokenizers\trainers
#   running build_ext
#   running build_rust
#   error: can't find Rust compiler
#
#   If you are using an outdated pip version, it is possible a prebuilt wheel is available for this package but pip is not able to install from it. Installing from the wheel would avoid the need for a Rust compiler.
#
#   To update pip, run:
#
#       pip install --upgrade pip
#
#   and then retry package installation.
#
#   If you did intend to build this package from source, try installing a Rust compiler from your system package manager and ensure it is on the PATH during installation. Alternatively, rustup (available at https://rustup.rs) is the recommended way to download and update the Rust compiler toolchain.
#   ----------------------------------------
#   ERROR: Failed building wheel for tokenizers
# ERROR: Could not build wheels for tokenizers which use PEP 517 and cannot be installed directly
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\AORUS\Desktop\Open_QG-master\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !python -m nltk.downloader punkt
# Out:
# C:\Users\AORUS\AppData\Local\Programs\Python\Python39\lib\runpy.py:127: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AORUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !git clone https://github.com/patil-suraj/question_generation.git
# Out:
# ^C

# %%
text = "Python is an interpreted, high-level, general-purpose programming language. Created by Guido van Rossum \
and first released in 1991, Python's design philosophy emphasizes code \
readability with its notable use of significant whitespace."

text2 = "Since December 2019, a number of novel coronavirus infections, mainly of lung disease, have been detected in Wuhan, Hubei Province. With the spread of the epidemic, such cases have also been found in other parts of China and abroad. The clinical characteristics of the virus infection are fever, dry cough, shortness of breath, low or low level of peripheral white blood cells and inflammatory changes on chest radiography. The pathogen was identified and named COVID-19 by the World Health Organization (WHO) as a novel Coronavirus belonging to the beta genus and designated as a Public Health Emergency of International Concern on 31 January 2020. PHEIC)."

text3 = "42 is the answer to life, universe and everything."

text4 = "Forrest Gump is a 1994 American comedy-drama film directed by Robert Zemeckis and written by Eric Roth. \
It is based on the 1986 novel of the same name by Winston Groom and stars Tom Hanks, Robin Wright, Gary Sinise, \
Mykelti Williamson and Sally Field. The story depicts several decades in the life of Forrest Gump (Hanks), \
a slow-witted but kind-hearted man from Alabama who witnesses and unwittingly influences several defining \
historical events in the 20th century United States. The film differs substantially from the novel."

# %% [markdown]
# ## Single task QA

# %%
# %cd question_generation
# Out:
# C:\Users\AORUS\Desktop\QG\question_generation\question_generation

# %%
from pipelines import pipeline

# %%
nlp = pipeline("question-generation")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 nlp = pipeline("question-generation")
#
# File ~\Desktop\QG\question_generation\pipelines.py:346, in pipeline(task, model, tokenizer, qg_format, ans_model, ans_tokenizer, use_cuda, **kwargs)
#     344         tokenizer = AutoTokenizer.from_pretrained(tokenizer[0], **tokenizer[1])
#     345     else:
# --> 346         tokenizer = AutoTokenizer.from_pretrained(tokenizer)
#     348 # Instantiate model if needed
#     349 if isinstance(model, str):
#
# File ~\Desktop\Open_QG-master\venv\lib\site-packages\transformers\models\auto\tokenization_auto.py:546, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     544 tokenizer_class_py, tokenizer_class_fast = TOKENIZER_MAPPING[type(config)]
#     545 if tokenizer_class_fast and (use_fast or tokenizer_class_py is None):
# --> 546     return tokenizer_class_fast.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     547 else:
#     548     if tokenizer_class_py is not None:
#
# File ~\Desktop\Open_QG-master\venv\lib\site-packages\transformers\tokenization_utils_base.py:1780, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1777     else:
#    1778         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 1780 return cls._from_pretrained(
#    1781     resolved_vocab_files,
#    1782     pretrained_model_name_or_path,
#    1783     init_configuration,
#    1784     *init_inputs,
#    1785     use_auth_token=use_auth_token,
#    1786     cache_dir=cache_dir,
#    1787     **kwargs,
#    1788 )
#
# File ~\Desktop\Open_QG-master\venv\lib\site-packages\transformers\tokenization_utils_base.py:1915, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, use_auth_token, cache_dir, *init_inputs, **kwargs)
#    1913 # Instantiate tokenizer.
#    1914 try:
# -> 1915     tokenizer = cls(*init_inputs, **init_kwargs)
#    1916 except OSError:
#    1917     raise OSError(
#    1918         "Unable to load vocabulary from file. "
#    1919         "Please check that the provided vocabulary is accessible and not corrupted."
#    1920     )
#
# File ~\Desktop\Open_QG-master\venv\lib\site-packages\transformers\models\t5\tokenization_t5_fast.py:130, in T5TokenizerFast.__init__(self, vocab_file, tokenizer_file, eos_token, unk_token, pad_token, extra_ids, additional_special_tokens, **kwargs)
#     124     if extra_tokens != extra_ids:
#     125         raise ValueError(
#     126             f"Both extra_ids ({extra_ids}) and additional_special_tokens ({additional_special_tokens}) are provided to T5Tokenizer. "
#     127             "In this case the additional_special_tokens must include the extra_ids tokens"
#     128         )
# --> 130 super().__init__(
#     131     vocab_file,
#     132     tokenizer_file=tokenizer_file,
#     133     eos_token=eos_token,
#     134     unk_token=unk_token,
#     135     pad_token=pad_token,
#     136     extra_ids=extra_ids,
#     137     additional_special_tokens=additional_special_tokens,
#     138     **kwargs,
#     139 )
#     141 self.vocab_file = vocab_file
#     142 self.can_save_slow_tokenizer = False if not self.vocab_file else True
#
# File ~\Desktop\Open_QG-master\venv\lib\site-packages\transformers\tokenization_utils_fast.py:118, in PreTrainedTokenizerFast.__init__(self, *args, **kwargs)
#     116     fast_tokenizer = convert_slow_tokenizer(slow_tokenizer)
#     117 else:
# --> 118     raise ValueError(
#     119         "Couldn't instantiate the backend tokenizer from one of: \n"
#     120         "(1) a `tokenizers` library serialization file, \n"
#     121         "(2) a slow tokenizer instance to convert or \n"
#     122         "(3) an equivalent slow tokenizer class to instantiate and convert. \n"
#     123         "You need to have sentencepiece installed to convert a slow tokenizer to a fast one."
#     124     )
#     126 self._tokenizer = fast_tokenizer
#     128 if slow_tokenizer is not None:
#
# ValueError: Couldn't instantiate the backend tokenizer from one of:
# (1) a `tokenizers` library serialization file,
# (2) a slow tokenizer instance to convert or
# (3) an equivalent slow tokenizer class to instantiate and convert.
# You need to have sentencepiece installed to convert a slow tokenizer to a fast one.

# %%
nlp(text3)

# %% [markdown]
# If you want to use the t5-base model, then pass the path through model parameter

# %%
nlp = pipeline("question-generation", model="valhalla/t5-base-qg-hl")

# %%
nlp(text3)

# %%
nlp(text4)

# %%
nlp(text2)

# %% [markdown]
# ## Multitask QA-QG

# %% [markdown]
# ### small-model

# %%
nlp = pipeline("multitask-qa-qg")

# %% [markdown]
# #### QG

# %%
nlp(text)

# %%
nlp(text2)

# %%
nlp(text4)

# %% [markdown]
# #### QA

# %%
nlp({
  "question": "Who created Python ?",
  "context": text
})

# %%
nlp({
    "question": "Who wrote Forrest Gump ?",
     "context": text4
})

# %% [markdown]
# ### base-model

# %%
nlp = pipeline("multitask-qa-qg", model="valhalla/t5-base-qa-qg-hl")

# %% [markdown]
# #### QG

# %%
nlp(text)

# %%
nlp(text2)

# %%
nlp(text4)

# %% [markdown]
# #### QA

# %%
nlp({
  "question": "Who created Python ?",
  "context": text
})

# %%
nlp({
    "question": "Who wrote Forrest Gump ?",
     "context": text4
})

# %% [markdown]
# ## End-to-End QG

# %% [markdown]
# ### small model

# %%
nlp = pipeline("e2e-qg")

# %%
nlp(text)

# %%
nlp(text2)

# %%
nlp(text4)

# %% [markdown]
# ### base-model

# %%
nlp = pipeline("e2e-qg", model="valhalla/t5-base-e2e-qg")

# %%
nlp(text)

# %%
nlp(text2)

# %%
nlp(text4)
